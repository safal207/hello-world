# %% [markdown]
# <a href="https://colab.research.google.com/github/safal207/hello-world/blob/master/%D0%98%D0%BC%D0%BF%D0%BE%D1%80%D1%82_%D0%B8_%D1%8D%D0%BA%D1%81%D0%BF%D0%BE%D1%80%D1%82_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_%D1%87%D0%B5%D1%80%D0%B5%D0%B7_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Как загрузить/выгрузить данные на/c Google Colaboratory (Виртуальной машине Linux)
#
#
# 1.   Скачать данные из интернета через команду !wget
# 2.   Загрузка данных на Виртуальную машину Linux ( Google Colab) c локального ПК
# 3.   Загрузка / Сохранение файлов с ВМ ( Google Colab) на локальный компьютер (ПК)
#
# 4.  Использование Google Drive
#
#
# *   Копирование данных с Google Drive на локальный диск виртуальной машины (ВМ - Google Colab)
# *   Копируем данные с диска виртуальной машины (ВМ - Google Colab) на Google Drive
#
# 5. Создаем Keras Callback для сохранения нейронной сети на Google Drive

# %% [markdown]
# ## Скачать данные из интернета через команду !wget
#
# Данные, которые находятся в открытом доступе в интернете можно скачать используя `wget`:

# %% [markdown]
# ###!wget

# %%
# !wget http://vis-www.cs.umass.edu/lfw/lfw-a.zip
# Out:
# --2020-11-18 14:15:12--  http://vis-www.cs.umass.edu/lfw/lfw-a.zip
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15167852 (14M) [application/zip]
# Saving to: ‘lfw-a.zip’
#
# lfw-a.zip           100%[===================>]  14.46M  9.57MB/s    in 1.5s
#
# 2020-11-18 14:15:14 (9.57 MB/s) - ‘lfw-a.zip’ saved [15167852/15167852]

# %% [markdown]
# ##2. Загрузка данных на Виртуальную машину Linux ( Google Colab) c локального ПК
#
# Загрузить данные с локального компьютера на Colaboratory, или наоборот, можно с помощью `python`, модуль `google.colab`

# %% [markdown]
# **Загрузка файлов с локального компьютера на ВМ (Colab)**

# %%
from google.colab import files
files.upload()

# %%
# !ls
# Out:
#  lfw-a.zip   sample_data  'Скриншот 30-09-2020 22.09.28.png'

# %%
from IPython.display import Image
Image('Скриншот 30-09-2020 22.09.28.png')

# %% [markdown]
# ## Загрузка / Сохранение файлов с ВМ ( Google Colab) на локальный компьютер (ПК)**

# %%
files.download("sample_data/california_housing_train.csv")

# %% [markdown]
# # Использование Google Drive
#
# Копирование больших файлов просходит значительно быстрее, если использовать Google Drive.
#
# Подключение Google Drive к виртуальной машине:
#
#
# *   `from google.colab import drive`
# *   `drive.mount('/путь_котологу/нужный_каталог')`
#
# force_remount=True)`

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###Команда linux `!df -h` Просматриваем подключенные диски

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   31G   78G  29% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.9G     0  5.9G   0% /dev/shm
# tmpfs           6.4G   16K  6.4G   1% /var/colab
# /dev/sda1       114G   32G   83G  28% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive            15G   11G  4.1G  73% /content/gdrive

# %% [markdown]
# Просматриваем содержимое диска

# %%
# !ls /content/gdrive/
# Out:
# MyDrive

# %%
# !ls /content/gdrive/"My Drive"
# Out:
#  11			       Python		        Концерт
#  AI			      'Sample file'	        Куратор
# 'Colab Notebooks'	      'Sample upload.txt'       Работа
#  EСXEL			       SQL		        Разное
#  foo.txt		       Базы		        Резюме
#  Foto			       Бм		       'Справочник Linux'
#  Linux			       Документы	       'Учеба ИИ'
# 'My cool spreadsheet.gsheet'  'Заметки в Play Книгах'   ШК

# %% [markdown]
# ##Копирование данных с Google Drive на локальный диск виртуальной машины (ВМ - Google Colab)

# %% [markdown]
# Найдите в своих папках архи и укажите путь

# %%
# !cp /content/gdrive/'My Drive'/Базы/base2.rar .

# %%
# !ls
# Out:
#  base2.rar   lfw-a.zip	  'Скриншот 30-09-2020 22.09.28.png'
#  gdrive      sample_data

# %% [markdown]
# ##Копируем данные с диска виртуальной машины (ВМ - Google Colab) на Google Drive

# %%
# !cp 'Скриншот 30-09-2020 22.09.28.png' /content/gdrive/'My Drive'/images

# %%
# !ls "'/content/gdrive/My Drive/images/'"
# Out:
# ls: cannot access "'/content/gdrive/My Drive/images/'": No such file or directory

# %% [markdown]
# #Создаем Keras Callback для сохранения нейронной сети на Google Drive

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
filepath="/content/gdrive/'My Drive'/deep_nets/mynet_best.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, 
                             save_best_only=True, mode='max')
