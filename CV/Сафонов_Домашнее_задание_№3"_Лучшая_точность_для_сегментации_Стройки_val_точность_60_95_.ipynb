# %% [markdown]
# <a href="https://colab.research.google.com/github/safal207/hello-world/blob/master/%D0%A1%D0%B0%D1%84%D0%BE%D0%BD%D0%BE%D0%B2_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%963%22_%D0%9B%D1%83%D1%87%D1%88%D0%B0%D1%8F_%D1%82%D0%BE%D1%87%D0%BD%D0%BE%D1%81%D1%82%D1%8C_%D0%B4%D0%BB%D1%8F_%D1%81%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D0%B8_%D0%A1%D1%82%D1%80%D0%BE%D0%B9%D0%BA%D0%B8_val_%D1%82%D0%BE%D1%87%D0%BD%D0%BE%D1%81%D1%82%D1%8C_60_95_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install aiuniver==1.2.4
# Out:
# Requirement already satisfied: aiuniver==1.2.4 in /usr/local/lib/python3.6/dist-packages (1.2.4)

# %%
from aiuniver import датасет
from aiuniver import модель

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1. Загрузите датасет стройки

# %%
(x_train, y_train), (x_test, y_test) = датасет.загрузить_базу_СТРОЙКА()
# Out:
# Загрузка данных
# Это может занять несколько минут...
# Загрузка данных (Готово)

# %% [markdown]
# 2. Посмотрите на примеры изображений

# %%
датасет.показать_примеры(
    изображения = x_train/255)

# %% [markdown]
# 3. Подберите архитектуру нейронной сети (линейная, PSP, UNET), которая будет давать минимум 60% точности (Обратите внимание, что количество классов в данном датасете равно 7). Поэтому казывайте этот параметр при создании своей сети.

# %%
# Ваше решение
модель_PSP = модель.создать_PSP(
    количество_фильтров = 26,
    входной_размер = x_train.shape[1:],
    количество_блоков = 4,
    количество_выходных_классов = 7
)
# Out:
# Создана модель нейронной сети!

# %% [markdown]
# 4. Тестирование модели

# %%
модель.структура_сети(модель_PSP)
# Out:
# Структура модели:
# _________________________________________________________________
# Model: "functional_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 176, 240, 3) 0
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 176, 240, 26) 728         input_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 176, 240, 26) 104         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 176, 240, 26) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 176, 240, 26) 6110        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 176, 240, 26) 104         conv2d_77[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 88, 120, 26)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 44, 60, 26)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 22, 30, 26)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 11, 15, 26)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 88, 120, 26)  6110        max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 44, 60, 26)   6110        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 22, 30, 26)   6110        max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 11, 15, 26)   6110        max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 176, 240, 26) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 176, 240, 26) 2730        conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 176, 240, 26) 10842       conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 176, 240, 26) 43290       conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_38 (Conv2DTran (None, 176, 240, 26) 173082      conv2d_81[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 176, 240, 159 0           input_11[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_35[0][0]
#                                                                  conv2d_transpose_35[0][0]
#                                                                  conv2d_transpose_36[0][0]
#                                                                  conv2d_transpose_37[0][0]
#                                                                  conv2d_transpose_38[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 176, 240, 26) 37232       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 176, 240, 26) 104         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 176, 240, 26) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 176, 240, 26) 6110        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 176, 240, 26) 104         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 176, 240, 26) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 176, 240, 7)  1645        activation_37[0][0]
# ==================================================================================================
# Total params: 306,625
# Trainable params: 306,417
# Non-trainable params: 208
# __________________________________________________________________________________________________
# None

# %%
модель.тест_модели_сегментации(
    модель = модель_PSP,
    тестовые_изображения = x_test,
    количество_классов = 7
)

# %%
# Обучаем модель
модель.обучение_модели(
    модель_PSP,
    x_train, y_train,
    x_test, y_test,
    batch_size = 45,
    epochs = 110)
# Out:
# Epoch 1/110
#  2/20 [==>...........................] - ETA: 9s - loss: 0.7958 - точность: 0.5872WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0379s vs `on_train_batch_end` time: 0.4675s). Check your callbacks.
# 20/20 [==============================] - 11s 532ms/step - loss: 0.8225 - точность: 0.5808 - val_loss: 1.1319 - val_точность: 0.5033
# Epoch 2/110
# 20/20 [==============================] - 11s 546ms/step - loss: 0.8196 - точность: 0.5798 - val_loss: 1.1267 - val_точность: 0.4902
# Epoch 3/110
# 20/20 [==============================] - 11s 551ms/step - loss: 0.8149 - точность: 0.5876 - val_loss: 1.1677 - val_точность: 0.5021
# Epoch 4/110
# 20/20 [==============================] - 11s 530ms/step - loss: 0.8081 - точность: 0.5891 - val_loss: 1.1315 - val_точность: 0.5193
# Epoch 5/110
# 20/20 [==============================] - 11s 527ms/step - loss: 0.8094 - точность: 0.5880 - val_loss: 1.2132 - val_точность: 0.5081
# Epoch 6/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.8042 - точность: 0.5913 - val_loss: 1.1332 - val_точность: 0.5061
# Epoch 7/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7986 - точность: 0.5936 - val_loss: 1.1113 - val_точность: 0.5288
# Epoch 8/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7943 - точность: 0.5962 - val_loss: 1.0888 - val_точность: 0.5115
# Epoch 9/110
# 20/20 [==============================] - 11s 527ms/step - loss: 0.7969 - точность: 0.5952 - val_loss: 1.0678 - val_точность: 0.5183
# Epoch 10/110
# 20/20 [==============================] - 11s 532ms/step - loss: 0.7910 - точность: 0.5977 - val_loss: 1.2243 - val_точность: 0.5016
# Epoch 11/110
# 20/20 [==============================] - 11s 529ms/step - loss: 0.7844 - точность: 0.6000 - val_loss: 1.1631 - val_точность: 0.5136
# Epoch 12/110
# 20/20 [==============================] - 11s 527ms/step - loss: 0.7837 - точность: 0.6041 - val_loss: 1.1083 - val_точность: 0.5253
# Epoch 13/110
# 20/20 [==============================] - 11s 530ms/step - loss: 0.7827 - точность: 0.6026 - val_loss: 1.0598 - val_точность: 0.5506
# Epoch 14/110
# 20/20 [==============================] - 11s 525ms/step - loss: 0.7790 - точность: 0.6042 - val_loss: 1.1005 - val_точность: 0.5342
# Epoch 15/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7753 - точность: 0.6068 - val_loss: 1.1218 - val_точность: 0.5346
# Epoch 16/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7756 - точность: 0.6069 - val_loss: 1.1195 - val_точность: 0.5239
# Epoch 17/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7709 - точность: 0.6068 - val_loss: 1.1737 - val_точность: 0.5060
# Epoch 18/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7743 - точность: 0.6062 - val_loss: 1.1779 - val_точность: 0.5163
# Epoch 19/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7701 - точность: 0.6085 - val_loss: 1.0965 - val_точность: 0.5399
# Epoch 20/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7622 - точность: 0.6132 - val_loss: 1.0797 - val_точность: 0.5473
# Epoch 21/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7671 - точность: 0.6121 - val_loss: 1.1998 - val_точность: 0.5099
# Epoch 22/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7639 - точность: 0.6104 - val_loss: 1.1628 - val_точность: 0.5293
# Epoch 23/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7655 - точность: 0.6131 - val_loss: 1.1296 - val_точность: 0.5568
# Epoch 24/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7652 - точность: 0.6101 - val_loss: 1.1576 - val_точность: 0.5393
# Epoch 25/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7597 - точность: 0.6133 - val_loss: 1.1720 - val_точность: 0.5128
# Epoch 26/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7529 - точность: 0.6174 - val_loss: 1.1706 - val_точность: 0.5290
# Epoch 27/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7545 - точность: 0.6152 - val_loss: 1.0620 - val_точность: 0.5618
# Epoch 28/110
# 20/20 [==============================] - 10s 519ms/step - loss: 0.7553 - точность: 0.6156 - val_loss: 1.1483 - val_точность: 0.5441
# Epoch 29/110
# 20/20 [==============================] - 10s 515ms/step - loss: 0.7490 - точность: 0.6187 - val_loss: 1.0462 - val_точность: 0.5575
# Epoch 30/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7504 - точность: 0.6193 - val_loss: 1.1332 - val_точность: 0.5465
# Epoch 31/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7441 - точность: 0.6212 - val_loss: 1.0631 - val_точность: 0.5534
# Epoch 32/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7469 - точность: 0.6192 - val_loss: 1.0076 - val_точность: 0.5886
# Epoch 33/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7434 - точность: 0.6223 - val_loss: 1.0575 - val_точность: 0.5540
# Epoch 34/110
# 20/20 [==============================] - 10s 519ms/step - loss: 0.7415 - точность: 0.6245 - val_loss: 1.1450 - val_точность: 0.4911
# Epoch 35/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7444 - точность: 0.6208 - val_loss: 1.1310 - val_точность: 0.5382
# Epoch 36/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7438 - точность: 0.6233 - val_loss: 1.1429 - val_точность: 0.5452
# Epoch 37/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7403 - точность: 0.6236 - val_loss: 1.2357 - val_точность: 0.5237
# Epoch 38/110
# 20/20 [==============================] - 10s 524ms/step - loss: 0.7365 - точность: 0.6238 - val_loss: 1.1193 - val_точность: 0.5741
# Epoch 39/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7344 - точность: 0.6252 - val_loss: 1.1701 - val_точность: 0.5639
# Epoch 40/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7340 - точность: 0.6279 - val_loss: 1.0958 - val_точность: 0.5671
# Epoch 41/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7279 - точность: 0.6274 - val_loss: 1.2031 - val_точность: 0.4994
# Epoch 42/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7319 - точность: 0.6278 - val_loss: 1.1140 - val_точность: 0.5601
# Epoch 43/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7243 - точность: 0.6319 - val_loss: 1.1967 - val_точность: 0.5453
# Epoch 44/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7288 - точность: 0.6301 - val_loss: 1.1078 - val_точность: 0.5425
# Epoch 45/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7308 - точность: 0.6290 - val_loss: 1.1801 - val_точность: 0.5657
# Epoch 46/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7209 - точность: 0.6320 - val_loss: 1.0566 - val_точность: 0.5787
# Epoch 47/110
# 20/20 [==============================] - 10s 518ms/step - loss: 0.7258 - точность: 0.6313 - val_loss: 1.1134 - val_точность: 0.5471
# Epoch 48/110
# 20/20 [==============================] - 10s 519ms/step - loss: 0.7195 - точность: 0.6337 - val_loss: 1.2225 - val_точность: 0.5436
# Epoch 49/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7224 - точность: 0.6319 - val_loss: 1.1241 - val_точность: 0.5519
# Epoch 50/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7195 - точность: 0.6338 - val_loss: 1.0583 - val_точность: 0.5982
# Epoch 51/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7184 - точность: 0.6365 - val_loss: 1.0969 - val_точность: 0.5653
# Epoch 52/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7180 - точность: 0.6339 - val_loss: 1.1709 - val_точность: 0.5118
# Epoch 53/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7214 - точность: 0.6343 - val_loss: 1.1079 - val_точность: 0.5490
# Epoch 54/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7171 - точность: 0.6346 - val_loss: 1.0392 - val_точность: 0.5592
# Epoch 55/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7146 - точность: 0.6359 - val_loss: 1.0627 - val_точность: 0.5731
# Epoch 56/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7085 - точность: 0.6380 - val_loss: 1.0620 - val_точность: 0.5577
# Epoch 57/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7119 - точность: 0.6392 - val_loss: 1.1523 - val_точность: 0.5961
# Epoch 58/110
# 20/20 [==============================] - 10s 525ms/step - loss: 0.7066 - точность: 0.6395 - val_loss: 1.0509 - val_точность: 0.5790
# Epoch 59/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7135 - точность: 0.6363 - val_loss: 1.0971 - val_точность: 0.5339
# Epoch 60/110
# 20/20 [==============================] - 10s 523ms/step - loss: 0.7095 - точность: 0.6393 - val_loss: 1.0678 - val_точность: 0.5865
# Epoch 61/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7136 - точность: 0.6359 - val_loss: 1.1376 - val_точность: 0.5691
# Epoch 62/110
# 20/20 [==============================] - 10s 517ms/step - loss: 0.7083 - точность: 0.6398 - val_loss: 1.1525 - val_точность: 0.5546
# Epoch 63/110
# 20/20 [==============================] - 10s 522ms/step - loss: 0.7044 - точность: 0.6400 - val_loss: 1.0703 - val_точность: 0.5543
# Epoch 64/110
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7089 - точность: 0.6415 - val_loss: 1.1078 - val_точность: 0.5305
# Epoch 65/110
# 20/20 [==============================] - 10s 521ms/step - loss: 0.7018 - точность: 0.6420 - val_loss: 1.1625 - val_точность: 0.5876
# Epoch 66/110
# 20/20 [==============================] - 11s 530ms/step - loss: 0.7024 - точность: 0.6396 - val_loss: 1.1213 - val_точность: 0.5504
# Epoch 67/110
# 20/20 [==============================] - 11s 540ms/step - loss: 0.7007 - точность: 0.6452 - val_loss: 1.0885 - val_точность: 0.5461
# Epoch 68/110
# 20/20 [==============================] - 11s 544ms/step - loss: 0.7016 - точность: 0.6428 - val_loss: 1.0546 - val_точность: 0.5649
# Epoch 69/110
# 20/20 [==============================] - 11s 537ms/step - loss: 0.7021 - точность: 0.6437 - val_loss: 1.4026 - val_точность: 0.5347
# Epoch 70/110
# 20/20 [==============================] - 11s 532ms/step - loss: 0.6988 - точность: 0.6430 - val_loss: 1.0151 - val_точность: 0.5789
# Epoch 71/110
# 20/20 [==============================] - 11s 529ms/step - loss: 0.7027 - точность: 0.6434 - val_loss: 1.2564 - val_точность: 0.5548
# Epoch 72/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6997 - точность: 0.6436 - val_loss: 1.1374 - val_точность: 0.5398
# Epoch 73/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6989 - точность: 0.6441 - val_loss: 1.2044 - val_точность: 0.5245
# Epoch 74/110
# 20/20 [==============================] - 11s 535ms/step - loss: 0.6963 - точность: 0.6435 - val_loss: 1.0618 - val_точность: 0.5711
# Epoch 75/110
# 20/20 [==============================] - 11s 538ms/step - loss: 0.6947 - точность: 0.6464 - val_loss: 0.9878 - val_точность: 0.5875
# Epoch 76/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6931 - точность: 0.6474 - val_loss: 1.0981 - val_точность: 0.5679
# Epoch 77/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6918 - точность: 0.6455 - val_loss: 1.1722 - val_точность: 0.5734
# Epoch 78/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6872 - точность: 0.6507 - val_loss: 1.1151 - val_точность: 0.5653
# Epoch 79/110
# 20/20 [==============================] - 11s 531ms/step - loss: 0.6873 - точность: 0.6476 - val_loss: 1.1694 - val_точность: 0.5684
# Epoch 80/110
# 20/20 [==============================] - 11s 531ms/step - loss: 0.6909 - точность: 0.6483 - val_loss: 1.1273 - val_точность: 0.5556
# Epoch 81/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6882 - точность: 0.6509 - val_loss: 1.1263 - val_точность: 0.5622
# Epoch 82/110
# 20/20 [==============================] - 11s 531ms/step - loss: 0.6844 - точность: 0.6482 - val_loss: 1.0940 - val_точность: 0.5883
# Epoch 83/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6821 - точность: 0.6523 - val_loss: 1.0718 - val_точность: 0.5563
# Epoch 84/110
# 20/20 [==============================] - 11s 536ms/step - loss: 0.6805 - точность: 0.6526 - val_loss: 1.0261 - val_точность: 0.5813
# Epoch 85/110
# 20/20 [==============================] - 11s 535ms/step - loss: 0.6837 - точность: 0.6542 - val_loss: 1.0750 - val_точность: 0.5643
# Epoch 86/110
# 20/20 [==============================] - 11s 531ms/step - loss: 0.6845 - точность: 0.6486 - val_loss: 1.0589 - val_точность: 0.6011
# Epoch 87/110
# 20/20 [==============================] - 11s 530ms/step - loss: 0.6820 - точность: 0.6542 - val_loss: 1.0977 - val_точность: 0.5695
# Epoch 88/110
# 20/20 [==============================] - 10s 525ms/step - loss: 0.6779 - точность: 0.6520 - val_loss: 1.1015 - val_точность: 0.5534
# Epoch 89/110
# 20/20 [==============================] - 11s 529ms/step - loss: 0.6805 - точность: 0.6544 - val_loss: 1.0665 - val_точность: 0.5999
# Epoch 90/110
# 20/20 [==============================] - 11s 527ms/step - loss: 0.6775 - точность: 0.6544 - val_loss: 1.1093 - val_точность: 0.5782
# Epoch 91/110
# 20/20 [==============================] - 11s 528ms/step - loss: 0.6793 - точность: 0.6538 - val_loss: 1.1060 - val_точность: 0.5633
# Epoch 92/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6789 - точность: 0.6549 - val_loss: 1.0520 - val_точность: 0.6095
# Epoch 93/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6772 - точность: 0.6550 - val_loss: 1.1526 - val_точность: 0.5636
# Epoch 94/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6752 - точность: 0.6568 - val_loss: 1.2669 - val_точность: 0.5468
# Epoch 95/110
# 20/20 [==============================] - 11s 532ms/step - loss: 0.6761 - точность: 0.6553 - val_loss: 1.0509 - val_точность: 0.5414
# Epoch 96/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6698 - точность: 0.6564 - val_loss: 1.2565 - val_точность: 0.5479
# Epoch 97/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6721 - точность: 0.6556 - val_loss: 1.1702 - val_точность: 0.5848
# Epoch 98/110
# 20/20 [==============================] - 11s 536ms/step - loss: 0.6706 - точность: 0.6593 - val_loss: 1.1122 - val_точность: 0.5650
# Epoch 99/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6735 - точность: 0.6569 - val_loss: 1.0300 - val_точность: 0.5986
# Epoch 100/110
# 20/20 [==============================] - 11s 535ms/step - loss: 0.6678 - точность: 0.6575 - val_loss: 1.0497 - val_точность: 0.5682
# Epoch 101/110
# 20/20 [==============================] - 11s 535ms/step - loss: 0.6765 - точность: 0.6566 - val_loss: 1.0277 - val_точность: 0.6018
# Epoch 102/110
# 20/20 [==============================] - 11s 536ms/step - loss: 0.6758 - точность: 0.6565 - val_loss: 1.0563 - val_точность: 0.5826
# Epoch 103/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6674 - точность: 0.6589 - val_loss: 1.2468 - val_точность: 0.5618
# Epoch 104/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6691 - точность: 0.6597 - val_loss: 1.0943 - val_точность: 0.5592
# Epoch 105/110
# 20/20 [==============================] - 11s 530ms/step - loss: 0.6670 - точность: 0.6588 - val_loss: 1.2101 - val_точность: 0.5290
# Epoch 106/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6677 - точность: 0.6585 - val_loss: 1.2516 - val_точность: 0.5926
# Epoch 107/110
# 20/20 [==============================] - 11s 534ms/step - loss: 0.6700 - точность: 0.6585 - val_loss: 1.3254 - val_точность: 0.5430
# Epoch 108/110
# 20/20 [==============================] - 11s 531ms/step - loss: 0.6663 - точность: 0.6596 - val_loss: 1.0462 - val_точность: 0.5655
# Epoch 109/110
# 20/20 [==============================] - 11s 532ms/step - loss: 0.6670 - точность: 0.6588 - val_loss: 1.0365 - val_точность: 0.5746
# Epoch 110/110
# 20/20 [==============================] - 11s 532ms/step - loss: 0.6661 - точность: 0.6610 - val_loss: 1.0569 - val_точность: 0.5908

# %% [markdown]
# Лушая точность Epoch 92/110
# 20/20 [==============================] - 11s 533ms/step - loss: 0.6789 - точность: 0.6549 - val_loss: 1.0520 - val_точность: 0.6095

# %%
модель.тест_модели_сегментации(
    модель = модель_PSP,
    тестовые_изображения = x_test,
    количество_классов = 7
)
