# %% [markdown]
# <a href="https://colab.research.google.com/github/safal207/hello-world/blob/master/%D0%A1%D0%90%D1%84%D0%BE%D0%BD%D0%BE%D0%B2_%D0%B3%D0%B5%D0%BD%D0%B5%D1%82%D0%B8%D0%BA%D0%B0%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install terra_ai==0.0.0.36

# %%
from terra_ai import терра_ии
# Out:
# Все нобходимые библиотеки установлены и готовы к работе

# %%
терра_ии.генетика.загрузить_модули()
# Out:
# Все модули установлены и готовы к работе

# %%
терра_ии.генетика.создать_дисплей(1400, 900)
# Out:
# Виртуальный дисплей создан

# %%
терра_ии.генетика.показать_пример('Ракета')
# Out:
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %%
размер_популяции = 100
количество_эпох = 40
коэфицент_мутации = 0.2
количество_выживших = 10
  
терра_ии.генетика.обучить_алгоритм(
    размер_популяции, 
    количество_эпох, 
    коэфицент_мутации, 
    количество_выживших
  )
# Out:
# Выполняется эпоха № 0 Время на выполнение:  1.9 сек,   Награда для 3-x лучших ботов [  0  -8 -26]
# Выполняется эпоха № 1 Время на выполнение:  1.6 сек,   Награда для 3-x лучших ботов [229 198  10]
# Выполняется эпоха № 2 Время на выполнение:  4.2 сек,   Награда для 3-x лучших ботов [213 206 192]
# Выполняется эпоха № 3 Время на выполнение:  2.4 сек,   Награда для 3-x лучших ботов [36 22 -2]
# Выполняется эпоха № 4 Время на выполнение:  6.7 сек,   Награда для 3-x лучших ботов [228 196 166]
# Выполняется эпоха № 5 Время на выполнение:  5.8 сек,   Награда для 3-x лучших ботов [266 209 208]
# Выполняется эпоха № 6 Время на выполнение: 10.3 сек,   Награда для 3-x лучших ботов [234 199 194]
# Выполняется эпоха № 7 Время на выполнение: 15.6 сек,   Награда для 3-x лучших ботов [241 238 234]
# Выполняется эпоха № 8 Время на выполнение: 13.3 сек,   Награда для 3-x лучших ботов [262 242 231]
# Выполняется эпоха № 9 Время на выполнение: 21.8 сек,   Награда для 3-x лучших ботов [265 252 248]
# ...

# %%
терра_ии.генетика.посадить_корабль()
# Out:
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>
# Поздравляем, вы посадили корабль!  Награда:  100 баллов

# %%
терра_ии.генетика.посадить_корабль()
# Out:
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>
# Поздравляем, вы посадили корабль!  Награда:  100 баллов

# %%
терра_ии.генетика.посадить_корабль()
# Out:
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>
# Поздравляем, вы посадили корабль!  Награда:  100 баллов
