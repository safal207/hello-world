# %% [markdown]
# <a href="https://colab.research.google.com/github/safal207/hello-world/blob/master/%D0%A1%D0%B0%D1%84%D0%BE%D0%BD%D0%BE%D0%B2_%D0%90_%D0%90_%D0%9F%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Рисовать графики сразу же
# %matplotlib inline

import re # регулярные выражения

# Статический вывод графики (графики отображаются в той ячейке, в которой используется plt.show())
import pandas as pd # Импортируем библиотеку обработки и анализа данных pandas
import matplotlib.pyplot as plt # Импортируем модуль pyplot библиотеки matplotlib для построения графиков
import datetime # Импортируем модуль datetime для обработки данных в формете даты
import numpy as np # Импортируем библиотеку numpy
from google.colab import files # Импортируем библиотеку files для работы с файлами

# %% [markdown]
# #Задание. База резюме headhunter.

# %% [markdown]
# ##Загружаем базу

# %%
# Для загрузки данных используем drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fixed_df = pd.read_csv('/content/drive/My Drive/Базы/hh (1).csv',sep=',') # Путь, куда вы скачали файл

# %% [markdown]
# ##Содержимое базы

# %%
fixed_df.head()
# Out:
#    Unnamed: 0  ...                            Авто
# 0           0  ...  Имеется собственный автомобиль
# 1           1  ...                      Не указано
# 2           2  ...                      Не указано
# 3           3  ...                      Не указано
# 4           4  ...                      Не указано
#
# [5 rows x 13 columns]

# %%
# Количество резюме и критерии
print(fixed_df.shape)
# Out:
# (66945, 13)

# %%
# Пример данных
n = 1 # Берем первое резюме
for i in range(len(fixed_df.values[n])): # Выводим значение каждой графы резюме
  print(i, " ", fixed_df.values[n][i])
# Out:
# 0   1
# 1   Мужчина ,  41 год , родился 14 января 1978
# 2   60 000 руб.
# 3   Старший IT инженер
# 4   Сочи , не готов к переезду , готов к командировкам
# 5    частичная занятость, полная занятость
# 6    гибкий график, полный день
# 7   Опыт работы 19 лет 2 месяца
#
# Старший IT инженер 60 000 руб. Информационные технологии, интернет, телеком Сетевые технологии Системная интеграция Системный администратор Занятость: частичная занятость, полная занятость График работы: гибкий график, полный день Опыт работы 19 лет 2 месяца Июнь 2012 — по настоящее время 6 лет 11 месяцев Эскорт-Центр, Москва, ЗАО Краснодарский край , www.escort-center.ru Информационные технологии, системная интеграция, интернет ... Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Услуги для бизнеса Безопасность, охранная деятельность Старший инженер сервисного центра Обязанности: Обеспечение бесперебойного функционирования информационных систем управления. Настройка и администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012 и других программных продуктов. Обслуживание it оборудования и локальных информационных сетей пунктов пропуска через Государственную границу: системы паспортного контроля, включающие программно-аппаратные комплексы; кабины паспортного контроля, информационно-поисковую систему (ИПС) углубленной и специальной проверки документов; системы видеонаблюдения; системы контроля доступа; системы телефонной и радиосвязи; монтаж компьютерных сетей.  Март 2000 — Июнь  2012 12 лет 4 месяца Южный проект Дьюти-Фри, ООО Краснодарский край Розничная торговля ... Розничная сеть (продуктовая) Продукты питания Безалкогольные напитки (продвижение, оптовая торговля) Безалкогольные напитки (производство) Старший инженер IT Обязанности: Администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012; Установка, настройка и контроль работы антивирусной защиты; Анализ, предупреждение и прогнозирование, устранение сбоев в работе информационных систем и локальных сетей; Обеспечение пользователей офисной техникой и ПК; обслуживание компьютерной техники, консультирование и обучение персонала; построение, инсталляция и администрирование локальных сетей, серверных платформ в офисах и магазинах компании; инсталляция и администрирование систем продаж в торговых подразделениях; администрирование доступа в интернет; администрирование системы электронной почты. Регион обслуживания: Сочи-Краснодар-Ростов. Достижения: построил, инсталлировал локальную сеть главного офиса; построил, инсталлировал и отладил 7 торговых локальных сетей в магазинах компании; непосредственно участвовал в разработке программного обеспечения для фискального оборудования и его внедрении во всех структурных подразделениях компании; добился стабильной, бесперебойной работы сетей и оборудования. Ключевые навыки Теперь резюме открыто всему интернету — изменить можно в настройках видимости. Active Directory Администрирование серверов Windows Настройка сетевых подключений Настройка ПО MS SQL Server Системное администрирование Офисная техника Монтаж оборудования Локальные сети Windows Os Администрирование сетевого оборудования Cистемы управления базами данных Закупка оргтехники и оборудования Windows 2003, 2008 Server Windows 10, Windows 8.1, Windows XP AD, MS SQL, Exchange, Lync, System Center обслуживание POS оборудования маршрутизация, коммутация, VoIP, QoS, IEEE 802.1 Возникли неполадки. Попробуйте еще раз. Обо мне Хобби: автоспорт Высшее образование 1999 Кликнув на название учебного заведения вы сможете найти кандидатов из этого вуза. СОЧИНСКИЙ ГОС. УНИВЕРСИТЕТ ТУРИЗМА И КУРОРТНОГО ДЕЛА (СГУТиКД), Краснодар Мировая экономика, Информационные системы и технологии 1994 Школа бизнеса "ОНИКС" менеджмент, менеджер Знание языков Русский — Родной Английский — C2 — В совершенстве Повышение квалификации, курсы 2008 Технология 3000 "Консультант Плюс" Гражданство, время в пути до работы Гражданство: Россия Разрешение на работу: Россия Желательное время в пути до работы: Не имеет значения
#
# Опыт работы 19 лет 2 месяца Июнь 2012 — по настоящее время 6 лет 11 месяцев Эскорт-Центр, Москва, ЗАО Краснодарский край , www.escort-center.ru Информационные технологии, системная интеграция, интернет ... Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Услуги для бизнеса Безопасность, охранная деятельность Старший инженер сервисного центра Обязанности: Обеспечение бесперебойного функционирования информационных систем управления. Настройка и администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012 и других программных продуктов. Обслуживание it оборудования и локальных информационных сетей пунктов пропуска через Государственную границу: системы паспортного контроля, включающие программно-аппаратные комплексы; кабины паспортного контроля, информационно-поисковую систему (ИПС) углубленной и специальной проверки документов; системы видеонаблюдения; системы контроля доступа; системы телефонной и радиосвязи; монтаж компьютерных сетей.  Март 2000 — Июнь  2012 12 лет 4 месяца Южный проект Дьюти-Фри, ООО Краснодарский край Розничная торговля ... Розничная сеть (продуктовая) Продукты питания Безалкогольные напитки (продвижение, оптовая торговля) Безалкогольные напитки (производство) Старший инженер IT Обязанности: Администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012; Установка, настройка и контроль работы антивирусной защиты; Анализ, предупреждение и прогнозирование, устранение сбоев в работе информационных систем и локальных сетей; Обеспечение пользователей офисной техникой и ПК; обслуживание компьютерной техники, консультирование и обучение персонала; построение, инсталляция и администрирование локальных сетей, серверных платформ в офисах и магазинах компании; инсталляция и администрирование систем продаж в торговых подразделениях; администрирование доступа в интернет; администрирование системы электронной почты. Регион обслуживания: Сочи-Краснодар-Ростов. Достижения: построил, инсталлировал локальную сеть главного офиса; построил, инсталлировал и отладил 7 торговых локальных сетей в магазинах компании; непосредственно участвовал в разработке программного обеспечения для фискального оборудования и его внедрении во всех структурных подразделениях компании; добился стабильной, бесперебойной работы сетей и оборудования.
#
# Июнь 2012 — по настоящее время 6 лет 11 месяцев Эскорт-Центр, Москва, ЗАО Краснодарский край , www.escort-center.ru Информационные технологии, системная интеграция, интернет ... Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Услуги для бизнеса Безопасность, охранная деятельность Старший инженер сервисного центра Обязанности: Обеспечение бесперебойного функционирования информационных систем управления. Настройка и администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012 и других программных продуктов. Обслуживание it оборудования и локальных информационных сетей пунктов пропуска через Государственную границу: системы паспортного контроля, включающие программно-аппаратные комплексы; кабины паспортного контроля, информационно-поисковую систему (ИПС) углубленной и специальной проверки документов; системы видеонаблюдения; системы контроля доступа; системы телефонной и радиосвязи; монтаж компьютерных сетей. 
#
# Март 2000 — Июнь  2012 12 лет 4 месяца Южный проект Дьюти-Фри, ООО Краснодарский край Розничная торговля ... Розничная сеть (продуктовая) Продукты питания Безалкогольные напитки (продвижение, оптовая торговля) Безалкогольные напитки (производство) Старший инженер IT Обязанности: Администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012; Установка, настройка и контроль работы антивирусной защиты; Анализ, предупреждение и прогнозирование, устранение сбоев в работе информационных систем и локальных сетей; Обеспечение пользователей офисной техникой и ПК; обслуживание компьютерной техники, консультирование и обучение персонала; построение, инсталляция и администрирование локальных сетей, серверных платформ в офисах и магазинах компании; инсталляция и администрирование систем продаж в торговых подразделениях; администрирование доступа в интернет; администрирование системы электронной почты. Регион обслуживания: Сочи-Краснодар-Ростов. Достижения: построил, инсталлировал локальную сеть главного офиса; построил, инсталлировал и отладил 7 торговых локальных сетей в магазинах компании; непосредственно участвовал в разработке программного обеспечения для фискального оборудования и его внедрении во всех структурных подразделениях компании; добился стабильной, бесперебойной работы сетей и оборудования.
#
#
# 8   Эскорт-Центр, Москва, ЗАО
# 9   Старший инженер сервисного центра
# 10   Высшее образование 1999  СОЧИНСКИЙ ГОС. УНИВЕРСИТЕТ ТУРИЗМА И КУРОРТНОГО ДЕЛА (СГУТиКД), Краснодар Мировая экономика, Информационные системы и технологии 1994 Школа бизнеса  "ОНИКС" менеджмент, менеджер
# 11   28.04.2019 11:44
# 12   Не указано

# %%
##############################################
####Убрать кодировку в описаниях \xa0 \n
##############################################
fixed_df = fixed_df.drop(fixed_df.columns[0],axis = 1) # Убираем первый столбец с продублированными индексами. Он нам не нужен

i=0
for j in range(12):  # Для каждого из столбцов таблицы
    for i in range(fixed_df.shape[0]): # По всем резюме
        if type(fixed_df.values[i][j])!=float: # если данные текстовые, то заменяем фрагменты кодировки ASCII на отсутствие символов
            fixed_df.values[i][j] = fixed_df.values[i][j].replace("\xa0","")
            fixed_df.values[i][j] = fixed_df.values[i][j].replace("\n"," ")

# %%
# Пример данных
n = 1 # Берем первое резюме
for i in range(len(fixed_df.values[n])): # Выводим значение каждой графы резюме
  print(i, " ", fixed_df.values[n][i])
# Out:
# 0   Мужчина ,  41год , родился 14 января 1978
# 1   60000 руб.
# 2   Старший IT инженер
# 3   Сочи , не готов к переезду , готов к командировкам
# 4    частичная занятость, полная занятость
# 5    гибкий график, полный день
# 6   Опыт работы 19 лет 2 месяца  Старший IT инженер 60000 руб. Информационные технологии, интернет, телеком Сетевые технологии Системная интеграция Системный администратор Занятость: частичная занятость, полная занятость График работы: гибкий график, полный день Опыт работы 19 лет 2 месяца Июнь2012 — понастоящеевремя 6 лет 11 месяцев Эскорт-Центр, Москва, ЗАО Краснодарский край , www.escort-center.ru Информационные технологии, системная интеграция, интернет ... Системная интеграция, автоматизации технологических и бизнес-процессов предприятия, ИТ-консалтинг Услуги для бизнеса Безопасность, охранная деятельность Старший инженер сервисного центра Обязанности: Обеспечение бесперебойного функционирования информационных систем управления. Настройка и администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012 и других программных продуктов. Обслуживание it оборудования и локальных информационных сетей пунктов пропуска через Государственную границу: системы паспортного контроля, включающие программно-аппаратные комплексы; кабины паспортного контроля, информационно-поисковую систему (ИПС) углубленной и специальной проверки документов; системы видеонаблюдения; системы контроля доступа; системы телефонной и радиосвязи; монтаж компьютерных сетей.  Март2000 — Июнь 2012 12 лет 4 месяца Южный проект Дьюти-Фри, ООО Краснодарский край Розничная торговля ... Розничная сеть (продуктовая) Продукты питания Безалкогольные напитки (продвижение, оптовая торговля) Безалкогольные напитки (производство) Старший инженер IT Обязанности: Администрирование Windows XP, Vista, 7, 8; Windows Server 2003, 2008, 2012; Установка, настройка и контроль работы антивирусной защиты; Анализ, предупреждение и прогнозирование, устранение сбоев в работе информационных систем и локальных сетей; Обеспечение пользователей офисной техникой и ПК; обслуживание компьютерной техники, консультирование и обучение персонала; построение, инсталляция и администрирование локальных сетей, серверных платформ в офисах и магазинах компании; инсталляция и администрирование систем продаж в торговых подразделениях; администрирование доступа в интернет; администрирование системы электронной почты. Регион обслуживания: Сочи-Краснодар-Ростов. Достижения: построил, инсталлировал локальную сеть главного офиса; построил, инсталлировал и отладил 7 торговых локальных сетей в магазинах компании; непосредственно участвовал в разработке программного обеспечения для фискального оборудования и его внедрении во всех структурных подразделениях компании; добился стабильной, бесперебойной работы сетей и оборудования. Ключевые навыки Теперь резюме открыто всему интернету — изменить можно в настройках видимости. Active Directory Администрирование серверов Windows Настройка сетевых подключений Настройка ПО MS SQL Server Системное администрирование Офисная техника Монтаж оборудования Локальные сети Windows Os Администрирование сетевого оборудования Cистемы управления базами данных Закупка оргтехники и оборудования Windows 2003, 2008 Server Windows 10, Windows 8.1, Windows XP AD, MS SQL, Exchange, Lync, System Center обслуживание POS оборудования маршрутизация, коммутация, VoIP, QoS, IEEE 802.1 Возникли неполадки. Попробуйте еще раз. Обо мне Хобби: автоспорт Высшее образование 1999 Кликнув на название учебного заведения вы сможете найти кандидатов из этого вуза. СОЧИНСКИЙ ГОС. УНИВЕРСИТЕТ ТУРИЗМА И КУРОРТНОГО ДЕЛА (СГУТиКД), Краснодар Мировая экономика, Информационные системы и технологии 1994 Школа бизнеса "ОНИКС" менеджмент, менеджер Знание языков Русский — Родной Английский — C2 — В совершенстве Повышение квалификации, курсы 2008 Технология 3000 "Консультант Плюс" Гражданство, время в пути до работы Гражданство: Россия Разрешение на работу: Россия Желательное время в пути до работы: Не имеет значения  Опыт работы 19 лет 2 месяца Июнь2012 — понастоящеевремя 6 лет 11 месяцев Эскорт-Центр, Москва, ЗАО Краснодарский край , www.escort-center.ru Информационные технологии, системная интеграция, интер ...
# 7   Эскорт-Центр, Москва, ЗАО
# 8   Старший инженер сервисного центра
# 9   Высшее образование 1999  СОЧИНСКИЙ ГОС. УНИВЕРСИТЕТ ТУРИЗМА И КУРОРТНОГО ДЕЛА (СГУТиКД), Краснодар Мировая экономика, Информационные системы и технологии 1994 Школа бизнеса  "ОНИКС" менеджмент, менеджер
# 10   28.04.2019 11:44
# 11   Не указано

# %% [markdown]
# ##Парсим базу

# %% [markdown]
# Версия для хранения

# %%
# Данные о поле и возрасте
def getParameterSexAge(arg):
  out = 0
  # Если М, то 1. По умолчанию 0 - Ж
  if "Муж" in arg:
    sex='М'
  elif "Жен" in arg:
    sex = 'Ж'
  else:
    sex = "Не указан"
  # Текущий год - год рождения
  year_tec = 2020
  if (len(arg) > 7):
    out = year_tec - int(re.findall(r'\d{4}', arg)[0])

  return sex, str(out)

# Зарплата
def getParameterSalary(arg):
    global salaryStr, num # т.к. используем, меняем в функции
    # Сначала получаем чистое число, убираем лишние знаки
    salaryStr = 0
    arg=str(arg)  
    salaryStr = int(re.sub(r'[^0-9]+', '', arg))
    curr_ = re.sub('[0-9]','',arg).replace('.','')

    # Конвертируем в рубли, если валюта
    if 'USD' in curr_ :   salaryStr = float(salaryStr)*75
    elif 'KZT' in curr_:  salaryStr = float(salaryStr)*0.17
    elif 'грн' in curr_:  salaryStr = float(salaryStr)*2.6
    num =salaryStr 
    return salaryStr


# Данные о городе
def getParameterCity(arg):
  millionCities = "Новосибирск Екатеринбург Нижний Новгород Казань Челябинск Омск Самара Ростов-на-Дону Уфа Красноярск Пермь Воронеж Волгоград Сочи"
  sarg=arg.split(',')
  item = sarg[0] # Берем только город
  item= item.strip() # Удаляем пробелы
  if item == "Москва":          return "Москва"
  if item == "Санкт-Петербург": return "Санкт-Петербург"
  if item in millionCities:     return item
  else: return "малый или за пределами России город"

# Данные о желаемой занятости
def getParameterEmployment(arg):
  result = ''
  if ("стажировка" in arg)|("volunteer" in arg)|("work placement" in arg): result += 'стажировка '
  if ("частичная занятость" in arg)|("part" in arg):  result += 'частичная занятость '
  if ("проектная работа" in arg)|("project" in arg):  result += 'проектная работа '
  if ("полная занятость" in arg)|("full" in arg):     result += 'полная занятость'
  if result=='':
    result='Не указано'
  return result

# Данные о желаемом графике работы
def getParameterSchedule(arg):
  result = ''
  if ("гибкий график" in arg)|("flexible" in arg):    result += 'гибкий график '
  if ("полный день" in arg)|("full" in arg):     result += 'полный день '
  if ("сменный график" in arg)|("shift" in arg):   result += 'сменный график '
  if ("удаленная работа" in arg)|("remote" in arg): result += 'удаленная работа'
  if result=='':
    result='Не указано'
  return result

# Данные об образовании
def getParameterEducation(arg):
  result = ''
  arg = arg.lower()
  if ("высшее" in arg)|("higher education"  in arg): result += 'высшее '
  if ("среднее специальное"  in arg) | ("special"  in arg) | ("колледж"  in arg) | ("college"  in arg) : result += 'среднее специальное '
  if ("неоконченное высшее"  in arg) | ("incomplete"  in arg): result += 'неоконченное высшее '
  if ("среднее образование"  in arg) | ("secondary education"  in arg): result += 'среднее образование'
  if result=='':
    result='Не указано'
  return result

# Данные об опыте работы
def getParameterExperience(arg):
  sarg=arg.split(" ", 5)
  years = 0
  months = 0
  if len(sarg)!=6: sarg.append(0);sarg.append('');sarg.append(0);sarg.append('')
  try:
    #print(sarg)
    years = int(sarg[2])
  except ValueError:
    years = 0

  try:
    months = int(sarg[4])
  except ValueError:
    months = 0
  return 12*years+months

# %%
fixed_df.head()
# Out:
#                                   Пол, возраст  ...                            Авто
# 0   Мужчина ,  42года , родился 6 октября 1976  ...  Имеется собственный автомобиль
# 1    Мужчина ,  41год , родился 14 января 1978  ...                      Не указано
# 2  Мужчина ,  44года , родился 21 февраля 1975  ...                      Не указано
# 3   Мужчина ,  43года , родился 9 февраля 1976  ...                      Не указано
# 4      Мужчина ,  39лет , родился 14 июня 1979  ...                      Не указано
#
# [5 rows x 12 columns]

# %%
df = fixed_df.drop(fixed_df.columns[[2,7,8,10,11]],axis=1 ) # Удаляем неинтересующие нас столбцы

# %%
df.head()
# Out:
#                                   Пол, возраст  ...                                  Образование и ВУЗ
# 0   Мужчина ,  42года , родился 6 октября 1976  ...       Среднее специальное образование 1994 Спту 26
# 1    Мужчина ,  41год , родился 14 января 1978  ...  Высшее образование 1999  СОЧИНСКИЙ ГОС. УНИВЕР...
# 2  Мужчина ,  44года , родился 21 февраля 1975  ...  Высшее образование 2003  Московский государств...
# 3   Мужчина ,  43года , родился 9 февраля 1976  ...  Высшее образование 2002  Российский государств...
# 4      Мужчина ,  39лет , родился 14 июня 1979  ...  Высшее образование 2007  Российский государств...
#
# [5 rows x 7 columns]

# %%
# Создаем список в которых лежат объекты наших функций
funcList = [getParameterSexAge,getParameterSalary, getParameterCity,getParameterEmployment,getParameterSchedule,getParameterExperience,getParameterEducation]

# Проходимся по каждой колонке и применяем к каждой из колонок соответствующую функцию
for i in range(len(df.columns)):
  df[df.columns[i]] =[ funcList[i](cell) for cell in df[df.columns[i]]]

# %%
df.head()
# Out:
#   Пол, возраст  ...     Образование и ВУЗ
# 0      (М, 44)  ...  среднее специальное
# 1      (М, 42)  ...               высшее
# 2      (М, 45)  ...               высшее
# 3      (М, 44)  ...               высшее
# 4      (М, 41)  ...               высшее
#
# [5 rows x 7 columns]

# %%
df.insert(0,'Пол', np.array([df['Пол, возраст'][i][0] for i in range(len(df))]))          # Создаем отдельную колонку под Пол 
df.insert(1,'Возраст', np.array([int(df['Пол, возраст'][i][1]) for i in range(len(df))])) # Создаем отдельную колонку под Возраст
df.drop('Пол, возраст', axis = 1, inplace = True)                                         # Убираем лишнюю колонку, сочетающую в себе эти два признака

# %%
df.head()
# Out:
#   Пол  Возраст  ...  Опыт (двойное нажатие для полной версии)     Образование и ВУЗ
# 0   М       44  ...                                        73  среднее специальное
# 1   М       42  ...                                       230               высшее
# 2   М       45  ...                                       237               высшее
# 3   М       44  ...                                        69               высшее
# 4   М       41  ...                                       161               высшее
#
# [5 rows x 8 columns]

# %%
df.to_csv('/content/drive/My Drive/Базы/hh_parsed.csv', index=False)  # Сохраняем распаршенную базу

# %%
fixed_df['Город'][2444]
# Out:
# 'Нижний Новгород ,  м. Горьковская , не готова к переезду , готова к редким командировкам'

# %%
f = 'Мама мыла раму, всем привет, как Ваши дела?'
f = f.split(',')
f[2]
# Out:
# ' как Ваши дела?'

# %%
sarg=fixed_df['Город'][1].split(',')
fixed_df['Город'][1]
# Out:
# 'Сочи , не готов к переезду , готов к командировкам'

# %%
sarg[1]
# Out:
# ' не готов к переезду '

# %%
df['Переезд'] = 'Нет данных'
df
# Out:
#       Пол  Возраст  ...     Образование и ВУЗ     Переезд
# 0       М       44  ...  среднее специальное   Нет данных
# 1       М       42  ...               высшее   Нет данных
# 2       М       45  ...               высшее   Нет данных
# 3       М       44  ...               высшее   Нет данных
# 4       М       41  ...               высшее   Нет данных
# ...    ..      ...  ...                   ...         ...
# 66940   М       24  ...   среднее образование  Нет данных
# 66941   М       28  ...               высшее   Нет данных
# 66942   М       56  ...               высшее   Нет данных
# 66943   Ж       33  ...               высшее   Нет данных
# 66944   М       34  ...               высшее   Нет данных
#
# [66945 rows x 9 columns]

# %%
fixed_df
# Out:
#                                        Пол, возраст  ...                            Авто
# 0        Мужчина ,  42года , родился 6 октября 1976  ...  Имеется собственный автомобиль
# 1         Мужчина ,  41год , родился 14 января 1978  ...                      Не указано
# 2       Мужчина ,  44года , родился 21 февраля 1975  ...                      Не указано
# 3        Мужчина ,  43года , родился 9 февраля 1976  ...                      Не указано
# 4           Мужчина ,  39лет , родился 14 июня 1979  ...                      Не указано
# ...                                             ...  ...                             ...
# 66940   Мужчина ,  22года , родился 4 сентября 1996  ...                      Не указано
# 66941     Мужчина ,  26лет , родился 2 декабря 1992  ...                      Не указано
# 66942    Мужчина ,  55лет , родился 21 февраля 1964  ...  Имеется собственный автомобиль
# 66943  Женщина ,  32года , родилась 23 февраля 1987  ...                      Не указано
# 66944       Мужчина ,  32года , родился 7 июня 1986  ...                      Не указано
#
# [66945 rows x 12 columns]

# %% [markdown]
# ## Сcылка на регулярные выражения https://tproger.ru/translations/regular-expression-python/

# %% [markdown]
# **Добавляем колонку "Переезд"**

# %%
# Добавляем колонку "Переезд"

for i in range(len(fixed_df['Город'])):
  sarg=fixed_df['Город'][i].split(',')
  for id, j in enumerate(sarg):
    if re.search(r'перее', j):
      df['Переезд'][i] = sarg[id]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df
# Out:
#       Пол  Возраст  ...     Образование и ВУЗ                               Переезд
# 0       М       44  ...  среднее специальное                   не готов к переезду
# 1       М       42  ...               высшее                   не готов к переезду
# 2       М       45  ...               высшее                      готов к переезду
# 3       М       44  ...               высшее                   не готов к переезду
# 4       М       41  ...               высшее                   не готов к переезду
# ...    ..      ...  ...                   ...                                   ...
# 66940   М       24  ...   среднее образование                хочу переехать (Москва
# 66941   М       28  ...               высшее    готов к переезду (Санкт-Петербург)
# 66942   М       56  ...               высшее    готов к переезду (Санкт-Петербург)
# 66943   Ж       33  ...               высшее                  не готова к переезду
# 66944   М       34  ...               высшее             готов к переезду (Беларусь
#
# [66945 rows x 9 columns]

# %% [markdown]
# **Добавляем колонку "Командировки"**

# %%
# Добавляем колонку "Командировки"
df['Командировки'] = 'Нет данных'
for i in range(len(fixed_df['Город'])):
  sarg=fixed_df['Город'][i].split(',')
  for id, j in enumerate(sarg):
    if re.search(r'команд', j):
      df['Командировки'][i] = sarg[id]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df
# Out:
#       Пол  ...                   Командировки
# 0       М  ...       не готов к командировкам
# 1       М  ...          готов к командировкам
# 2       М  ...          готов к командировкам
# 3       М  ...   готов к редким командировкам
# 4       М  ...   готов к редким командировкам
# ...    ..  ...                            ...
# 66940   М  ...          готов к командировкам
# 66941   М  ...          готов к командировкам
# 66942   М  ...          готов к командировкам
# 66943   Ж  ...         готова к командировкам
# 66944   М  ...          готов к командировкам
#
# [66945 rows x 10 columns]

# %%
df['Командировки'].value_counts()
# Out:
#  готов к командировкам            24854
#  не готов к командировкам         15354
#  готов к редким командировкам     12366
#  не готова к командировкам         5031
#  готова к командировкам            4445
#  готова к редким командировкам     3005
# Нет данных                         1885
#  готов к команд                       3
#  готов к командир                     1
#  готов к командировка                 1
# Name: Командировки, dtype: int64

# %%
df
# Out:
#       Пол  ...                   Командировки
# 0       М  ...       не готов к командировкам
# 1       М  ...          готов к командировкам
# 2       М  ...          готов к командировкам
# 3       М  ...   готов к редким командировкам
# 4       М  ...   готов к редким командировкам
# ...    ..  ...                            ...
# 66940   М  ...          готов к командировкам
# 66941   М  ...          готов к командировкам
# 66942   М  ...          готов к командировкам
# 66943   Ж  ...         готова к командировкам
# 66944   М  ...          готов к командировкам
#
# [66945 rows x 10 columns]

# %% [markdown]
# # Задание. База с Юлы

# %% [markdown]
# **Загрузка данных**

# %%
df = pd.read_csv('/content/drive/My Drive/Базы/moscow.csv', sep=";") # Загружаем данные в data frame
df # Отображаем данные
# Out:
#               Комнат  ...                                         Примечание
# 0                  1  ...  Собственность оформлена! Ключи на руках! Опера...
# 1       Для заметок:  ...                                                NaN
# 2                  1  ...  Зеленоград к.1820 однокомнатная квартира общ.3...
# 3       Для заметок:  ...                                                NaN
# 4                  1  ...  Уютная, светлая квартира, застекленный балкон ...
# ...              ...  ...                                                ...
# 252531  Для заметок:  ...                                                NaN
# 252532            Ст  ...  Продается студия с отделкой в новом монолитном...
# 252533  Для заметок:  ...                                                NaN
# 252534            Ст  ...  ДАМЫ И ГОСПОДА! ВАШЕМУ ВНИМАНИЮ ПРЕДЛАГАЕТСЯ С...
# 252535  Для заметок:  ...                                                NaN
#
# [252536 rows x 14 columns]

# %% [markdown]
# **1. Убираем строки "Для заметок"**

# %%
df = df[df['Комнат'] != 'Для заметок:'] # Оставляем в таблице только те строки, у которых в графе "Комнат" нет записи "Для заметок"
df # Смотрим результат
# Out:
#        Комнат  ...                                         Примечание
# 0           1  ...  Собственность оформлена! Ключи на руках! Опера...
# 2           1  ...  Зеленоград к.1820 однокомнатная квартира общ.3...
# 4           1  ...  Уютная, светлая квартира, застекленный балкон ...
# 6           1  ...  Предлагаю 1- комн квартиру, в шаговой доступно...
# 8           1  ...  Продается хорошая 1 комнатная квартира. 1 взро...
# ...       ...  ...                                                ...
# 252526     Ст  ...  Уникальнейшее предложение! 7 минуты до метро! ...
# 252528     Ст  ...  ВЫГОДНОЕ ПРЕДЛОЖЕНИЕ в пешей доступности от ме...
# 252530     Ст  ...  СТУДИЯ В МОСКВЕ ПО ДОСТУПНОЙ ЦЕНЕ ! __________...
# 252532     Ст  ...  Продается студия с отделкой в новом монолитном...
# 252534     Ст  ...  ДАМЫ И ГОСПОДА! ВАШЕМУ ВНИМАНИЮ ПРЕДЛАГАЕТСЯ С...
#
# [126268 rows x 14 columns]

# %%
df = df.reset_index(drop = True) # Переназначим индекс с удалением предыдущего индекса
df # Смотрим результат
# Out:
#        Комнат  ...                                         Примечание
# 0           1  ...  Собственность оформлена! Ключи на руках! Опера...
# 1           1  ...  Зеленоград к.1820 однокомнатная квартира общ.3...
# 2           1  ...  Уютная, светлая квартира, застекленный балкон ...
# 3           1  ...  Предлагаю 1- комн квартиру, в шаговой доступно...
# 4           1  ...  Продается хорошая 1 комнатная квартира. 1 взро...
# ...       ...  ...                                                ...
# 126263     Ст  ...  Уникальнейшее предложение! 7 минуты до метро! ...
# 126264     Ст  ...  ВЫГОДНОЕ ПРЕДЛОЖЕНИЕ в пешей доступности от ме...
# 126265     Ст  ...  СТУДИЯ В МОСКВЕ ПО ДОСТУПНОЙ ЦЕНЕ ! __________...
# 126266     Ст  ...  Продается студия с отделкой в новом монолитном...
# 126267     Ст  ...  ДАМЫ И ГОСПОДА! ВАШЕМУ ВНИМАНИЮ ПРЕДЛАГАЕТСЯ С...
#
# [126268 rows x 14 columns]

# %% [markdown]
# **2. Удаляем столбцы "Примечание" и "ГРМ"**

# %%
del df['Примечание'] # Удаляем "Примечание"

# %%
del df['ГРМ'] # Удаляем "ГРМ"

# %%
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %% [markdown]
# **3. Для столбца "Балкон" вместо Nan-значений создаем категорию "Отсутсвует"**

# %%
df.loc[df['Балкон'].isna(), 'Балкон'] = 'Отсутствует'
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %% [markdown]
# **4. Значения столбца "Бонус агенту" переводим в тысячи рублей, остальные значения заполняем нулями**

# %%
df.loc[df['Бонус агенту'].isna(), 'Бонус агенту'] = 0 # Зададим значение 0 для Nan-значений

# %%
bonus = df['Бонус агенту'] # Возьмем столбец "Бонус агенту"
cost = df['Цена, руб.']    # Возьмем столбец 'Цена, руб.'

# %%
pd.options.mode.chained_assignment = None # Отключаем warnings

for i in range(bonus.shape[0]): # Пройдем по всем значениям столбца "Бонус агенту"

  # Если значение является строкой (не 0, где раньше был Nan) и в нем есть 
  # подстрока 'руб.', значит в столбце явно указана сумма ганорара
  if isinstance(bonus[i], str) and bonus[i].find('руб.') != -1:  
    bonus[i] = bonus[i][:bonus[i].find('руб.')] # Оставляем только численное значение ганорара 
    bonus[i] = bonus[i].replace(' ', '')        # Удаляем пробелы,
    bonus[i] = float(bonus[i])                  # Переводим в float
    bonus[i] = bonus[i] / 1000                  # Делим на 1000

  # Если значение является строкой (не 0, где раньше был Nan) и в нем есть 
  # подстрока '%', значит в столбце ганорар указан в процентах от сделки
  elif isinstance(bonus[i], str) and bonus[i].find('%') != -1: 
    bonus[i] = bonus[i][:bonus[i].find('%')] # Оставляем только процентное значение ганорара 
    bonus[i] = bonus[i].replace(' ', '')     # Удаляем пробелы,
    bonus[i] = float(bonus[i])               # Переводим в float
    bonus[i] = bonus[i] / 100                # Делим на 100 (так как это проценты)
    bonus[i] = bonus[i] * cost[i]            # Умножаем на значение сделки
    bonus[i] = bonus[i] / 1000               # Делим на 1000
    
df['Бонус агенту'] = bonus # Сформированный массив присваиваем к столбцу
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %%
df.rename(columns={'Бонус агенту': 'Бонус агенту, тыс. руб.'}, inplace=True) # Даем новое название столбцу
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %%
df.loc[df['Бонус агенту, тыс. руб.'] != 0, 'Бонус агенту, тыс. руб.'] # Посмотрим на ненулевые значения
# Out:
# 152          10
# 304          10
# 319          10
# 388          50
# 456        70.5
#           ...
# 124244       20
# 124510        5
# 124753    10.15
# 125287      150
# 125843       50
# Name: Бонус агенту, тыс. руб., Length: 1252, dtype: object

# %% [markdown]
# **5. Считаем в цикле суммарную площадь помещений**

# %%
# Функция получения суммарной площади числа. На вход передаем строку столбца "Площадь". 
# В этом столбце попадаются записи, не соответсвующие формату, например, в некоторых ячейках имеется дата, хотя это столбец "Площадь"
# Суммарное значение площади может быть неизвестно. В этом случае будем вносить в таблицу 0

def parcer(strg):
  result = 0                            # Создаем возвращаемую переменную и приравниваем к 0
  if strg.find('/') != -1:              # Если в строке есть '/'
    strg = strg[:strg.find('/')]        # Берем все, что находится до него
    search=re.compile(r'[0-9.]').search # Создаем элемент для поиска недопустимых символов 
    if bool(search(strg)): # Проверяем наличие недопустимых символов. Если есть, то coorectSymbols = False, иначе True 
      result = float(strg) # Преобразуем в float

  return result            # Возвращаем результат 

areas = df['Площадь']      # Берем все записи в столбце "Площадь" 
finalAreas = []            # Создаем новый список, в который будем добавлять площади
for i in range(areas.shape[0]):         # Проходим по всем строчкам столбца
  finalAreas.append(parcer(areas[i]))   # Добавляем в список значение площади

df['Площадь'] = finalAreas # Меняем значения площадей помещений
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %% [markdown]
# **6. Отсутствующие значения в столбце "Санузел" меняем на "Нет данных"**

# %%
df.loc[df['Санузел'].isna(), 'Санузел'] = 'Нет данных'
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %% [markdown]
# **7. Переводим значение столбца 'Цена, руб.' В тысячи**

# %%
df['Цена, руб.'] = df['Цена, руб.'] / 1000

# %%
df.rename(columns={'Цена, руб.': 'Цена, тыс. руб.'}, inplace=True) # Даем новое название столбцу
df # Смотрим результат
# Out:
#        Комнат  Метро / ЖД станции  ... Кол-во дней в экспозиции         Источник
# 0           1         Шелепиха м.  ...                      1.0  Привлекательные
# 1           1  Пятницкое шоссе м.  ...                      2.0  Привлекательные
# 2           1        Планерная м.  ...                      4.0  Привлекательные
# 3           1      Шаболовская м.  ...                      7.0  Привлекательные
# 4           1     Бабушкинская м.  ...                     11.0  Привлекательные
# ...       ...                 ...  ...                      ...              ...
# 126263     Ст       Некрасовка м.  ...                     14.0         AVITO.ru
# 126264     Ст     Авиамоторная м.  ...                     14.0           Яндекс
# 126265     Ст      Коломенская м.  ...                     14.0         AVITO.ru
# 126266     Ст        Алтуфьево м.  ...                     14.0         AVITO.ru
# 126267     Ст         Волжская м.  ...                     14.0         AVITO.ru
#
# [126268 rows x 12 columns]

# %%
df['Дата'].unique()
# Out:
# array(['25.07.2019', '24.07.2019', '23.07.2019', '22.07.2019',
#        '21.07.2019', '20.07.2019', '18.07.2019', '17.07.2019',
#        '16.07.2019', '15.07.2019', '14.07.2019', '12.07.2019',
#        '19.07.2019', '13.07.2019', '11.07.2019', '10.07.2019',
#        '08.07.2019', '05.07.2019', '03.07.2019', '01.07.2019',
#        '07.07.2019', '09.07.2019', '25.06.2019', '21.06.2019',
#        '20.06.2019', '04.07.2019', '30.06.2019', '28.06.2019',
#        '14.06.2019', '06.06.2019', '26.06.2019', '05.06.2019',
#        '02.07.2019', '18.06.2019', '23.06.2019', '24.06.2019',
#        '27.06.2019', '09.06.2019', '06.07.2019', '19.06.2019',
#        '13.06.2019', '17.06.2019', '29.06.2019', '22.06.2019',
#        '12.06.2019', '10.06.2019', '08.06.2019', '07.06.2019',
#        '11.06.2019', '16.06.2019', '15.06.2019', '26.07.2019',
#        '03.08.2019', '02.08.2019', '01.08.2019', '31.07.2019',
#        '30.07.2019', '29.07.2019', '28.07.2019', '27.07.2019'],
#       dtype=object)
